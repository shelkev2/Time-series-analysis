# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

path='E:/ML/New Year Resolution.xlsx'
df=pd.read_excel(path)
df
# Out:
#        Month  diet: (Worldwide)  gym: (Worldwide)  finance: (Worldwide)
# 0    2004-01                100                31                    48
# 1    2004-02                 75                26                    49
# 2    2004-03                 67                24                    47
# 3    2004-04                 70                22                    48
# 4    2004-05                 72                22                    43
# 5    2004-06                 64                24                    45
# 6    2004-07                 60                23                    44
# 7    2004-08                 59                28                    44
# 8    2004-09                 53                25                    44
# 9    2004-10                 52                24                    45
# 10   2004-11                 50                23                    43
# 11   2004-12                 42                24                    41
# ...

# %%
df.info()   # info about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 4 columns):
# Month                   168 non-null object
# diet: (Worldwide)       168 non-null int64
# gym: (Worldwide)        168 non-null int64
# finance: (Worldwide)    168 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 5.3+ KB

# %%
df.columns = ['month', 'diet', 'gym', 'finance']
df.head()
# Out:
#      month  diet  gym  finance
# 0  2004-01   100   31       48
# 1  2004-02    75   26       49
# 2  2004-03    67   24       47
# 3  2004-04    70   22       48
# 4  2004-05    72   22       43

# %%
# .to_datetime() to convert the 'month' column in your DataFrame to a DateTime.


df.month = pd.to_datetime(df.month)
df.set_index('month', inplace=True)
df
# Out:
#             diet  gym  finance
# month
# 2004-01-01   100   31       48
# 2004-02-01    75   26       49
# 2004-03-01    67   24       47
# 2004-04-01    70   22       48
# 2004-05-01    72   22       43
# 2004-06-01    64   24       45
# 2004-07-01    60   23       44
# 2004-08-01    59   28       44
# 2004-09-01    53   25       44
# 2004-10-01    52   24       45
# 2004-11-01    50   23       43
# 2004-12-01    42   24       41
# 2005-01-01    64   32       44
# 2005-02-01    54   28       48
# 2005-03-01    56   27       46
# 2005-04-01    56   25       44
# 2005-05-01    59   24       42
# 2005-06-01    53   25       44
# 2005-07-01    53   25       44
# 2005-08-01    51   28       44
# 2005-09-01    47   28       44
# 2005-10-01    46   27       43
# 2005-11-01    44   25       42
# 2005-12-01    40   24       38
# 2006-01-01    64   34       44
# 2006-02-01    51   29       44
# 2006-03-01    51   28       46
# 2006-04-01    50   27       47
# 2006-05-01    50   26       45
# ...

# %%
# lets plot data vs date time
df.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
# if want particular column to plot
df[['diet']].plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
# Trends and Seasonality in Time Series Data
# Identifying Trends in Time Series
#There are several ways to think about identifying trends in time series. One popular way is by taking 
#a rolling average, which means that, for each time point, you take the average of the points on either
#side of it. Note that the number of points is specified by a window size, which you need to choose

# %%
#you take the average is it tends to smooth out noise and seasonality

diet = df[['diet']]
diet.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
gym = df[['gym']]
gym.rolling(12).mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
# You have removed most of the seasonality compared to the previous plot.

# %%
df_rm = pd.concat([diet.rolling(12).mean(), gym.rolling(12).mean()], axis=1)
df_rm.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
#Seasonal Patterns in Time Series Data
'''
One way to think about the seasonal components to the time series of your data is to remove the trend from a time series,
so that you can more easily investigate seasonality. To remove the trend, you can subtract the trend you computed above
(rolling mean) from the original signal. This, however, will be dependent on how many data points you averaged over.

Another way to remove the trend is called "differencing", where you look at the difference between successive data points
(called "first-order differencing", because you're only looking at the difference between one data point and the one before it).

'''
# Out:
# '\nOne way to think about the seasonal components to the time series of your data is to remove the trend from a time series,\nso that you can more easily investigate seasonality. To remove the trend, you can subtract the trend you computed above\n(rolling mean) from the original signal. This, however, will be dependent on how many data points you averaged over.\n\nAnother way to remove the trend is called "differencing", where you look at the difference between successive data points\n(called "first-order differencing", because you\'re only looking at the difference between one data point and the one before it).\n\n'

# %%
#First-order differencing
#You can use pandas and the diff() and plot() methods to compute and plot the first order difference of the 'diet' Series:

diet.diff().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20)
# Out:
# Text(0.5, 0, 'Year')

# %%
# time series prediction are easy on stationary data so always convert 
# Nonn stationary to stationary using above method or other methods present.
